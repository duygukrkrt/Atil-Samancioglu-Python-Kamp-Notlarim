# %%
myString = "hello world"

# %%
myString.split()
# Out:
# ['hello', 'world']

# %%
type(myString.split())
# Out:
# list

# %%
myString
# Out:
# 'hello world'

# %%
myString[6]
# Out:
# 'w'

# %%
#myString[6] = "c"

# %%
#immutable - immutability python da string veri tipi immutable(değiştirilemez).Bir metni bir kez oluşturduktan sonra, onun sadece tek bir harfini doğrudan değiştiremezsin.

# %%
myString = "duygu"

# %% [markdown]
# # list

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
x = 34
y = 45
z = 67

# %%
myList = [x,y,z]

# %%
myList
# Out:
# [34, 45, 67]

# %%
myList = [21,34,56,12,39,86]

# %%
myList[4]
# Out:
# 39

# %%
type(myList) #listenin kendisinin türü bir "LİSTE"dir.
# Out:
# list

# %%
type(myList[4]) #Ama listenin 4.elemanı olan 39 sayısının türü bir "TAM SAYI"dır(integer).
# Out:
# int

# %%
myList[4] = 90

# %%
#mutable, mutability değişebilirlik

# %%
myList
# Out:
# [21, 34, 56, 12, 90, 86]

# %%
len(myList) #listede kaç eleman olduğunu sayar.
# Out:
# 6

# %%
myList[len(myList)-1] # listenin son elemanını verir.
# Out:
# 86

# %%
myList[-1] # listenin son elemanını verir.
# Out:
# 86

# %%
myList[-2] # sondan bir önceki elemanı verir.
# Out:
# 90

# %%
myList
# Out:
# [21, 34, 56, 12, 90, 86]

# %%
myList.append(2) # listenin sonuna yeni bir eleman ekler.

# %%
myList
# Out:
# [21, 34, 56, 12, 90, 86, 2]

# %%
len(myList)
# Out:
# 7

# %%
myList.count(35) # count - aradığın elemandan listede kaç tane olduğunu söyler.
# Out:
# 0

# %%
help(myList.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
myList
# Out:
# [21, 34, 56, 12, 90, 86, 2]

# %%
myList.insert(3,78) # istediğin indekse yeni bir eleman yerleştir.

# %%
myList
# Out:
# [21, 34, 56, 78, 12, 90, 86, 2]

# %%
myList.pop() #listenin sonundaki elemanı siler ve sildiği elemanı çıktı olarak gösterir.
# Out:
# 2

# %%
myList
# Out:
# [21, 34, 56, 78, 12, 90, 86]

# %%
myList.remove(21) #doğrudan elemanın kendisini siler.

# %%
myList
# Out:
# [34, 56, 78, 12, 90, 86]

# %%
myList.reverse() # listeyi ters çevirir.

# %%
myList
# Out:
# [86, 90, 12, 78, 56, 34]

# %%
myList.sort() # listeyi küçükten büyüğe doğru dizer.

# %%
myList
# Out:
# [12, 34, 56, 78, 86, 90]

# %%
# kullanıcıdan bilgi almak için input değeri kullanılır.

# %%
x = input("enter x")
# Out:
# enter x 45

# %%
x
# Out:
# '45'

# %%
type(x)
# Out:
# str

# %%
y = input("enter y")
# Out:
# enter y 67

# %%
y
# Out:
# '67'

# %%
z = input("enter z")
# Out:
# enter z 89

# %%
z
# Out:
# '89'

# %%
inputList = []

# %%
type(inputList)
# Out:
# list

# %%
len(inputList)
# Out:
# 0

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['45', '67', '89']

# %%
inputList[2]
# Out:
# '89'

# %%
inputList[2]*2 # string türünde olduğu için iki sayıyı birleştirdi.
# Out:
# '8989'

# %%
type(inputList[2])
# Out:
# str

# %%
myInteger = 47

# %%
str(myInteger)
# Out:
# '47'

# %%
myString = "90"

# %%
int(myString)
# Out:
# 90

# %%
float(myString)
# Out:
# 90.0

# %%
inputList
# Out:
# ['45', '67', '89']

# %%
int(inputList[1]) * 2 # int türünde olduğu için iki sayıyı çarptı.
# Out:
# 134

# %%
inputList #liste
# Out:
# ['45', '67', '89']

# %%
str(inputList) # bu artık bir liste değil, düz bir string olduğunu gösterir.
# Out:
# "['45', '67', '89']"

# %%
nameList = ["duygu","karakurt","c","d"]

# %%
type(nameList)
# Out:
# list

# %%
floatList = [ 23.4,56.0,0,90,4.7]

# %%
type(floatList)
# Out:
# list

# %%
mixedList = ["duygu",28,2.6]

# %%
type(mixedList)
# Out:
# list

# %%
list1 = [1,2,3]
list2 = [4,5,6]

# %%
list1 + list2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
list1 * 2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
type(mixedList[2])
# Out:
# float

# %%
#nested iç içe liste

# %%
myNestedList = [1,2,6.8,"duygu",[5,6,7,8]]

# %%
myNestedList[4]
# Out:
# [5, 6, 7, 8]

# %%
x = myNestedList[0]

# %%
x
# Out:
# 1

# %%
smallList = myNestedList[4]

# %%
smallList
# Out:
# [5, 6, 7, 8]

# %%
type(smallList)
# Out:
# list

# %%
myNestedList
# Out:
# [1, 2, 6.8, 'duygu', [5, 6, 7, 8]]

# %%
smallList = myNestedList[-1]

# %%
smallList
# Out:
# [5, 6, 7, 8]

# %%
myNestedList[4][1]
# Out:
# 6

# %%
lastList = ["k","l",["m","n","o","p"],"r"]

# %%
len(lastList)
# Out:
# 4

# %%
lastList[2][3]
# Out:
# 'p'

# %%
firstList = [1,2,3,4,5,6,7,8,9,0]

# %%
firstList[::]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]

# %%
firstList[1:2:4]
# Out:
# [2]

# %%
firstList[2::]
# Out:
# [3, 4, 5, 6, 7, 8, 9, 0]

# %%
firstList[:2:]
# Out:
# [1, 2]

# %%
firstList[::2]
# Out:
# [1, 3, 5, 7, 9]

# %%
firstList[2:2:2]
# Out:
# []

# %%
y = 3

# %%
x = 9

# %%
x > y
# Out:
# True

# %%
y > x
# Out:
# False

# %%
y = 9

# %%
x <= y
# Out:
# True

# %%
x >= y
# Out:
# True

# %%
x >= 9.0
# Out:
# True

# %%
x >= 9.001
# Out:
# False

# %%
x = 45

# %%
y = 6

# %%
x = y # değer ataması yaptık yani y'deki degeri x'e atadık.

# %%
x
# Out:
# 6

# %%
y
# Out:
# 6

# %%
x = 34

# %%
y = 67

# %%
x == y # iki deger esit mi
# Out:
# False

# %%
x != y # esit degildir.
# Out:
# True

# %%
8 > 5 and 1 > 0
# Out:
# True

# %%
8 > 5 and 0 > 1
# Out:
# False

# %%
8 > 5 or 0 > 1
# Out:
# True

# %%
5 > 8 or 0 > 1
# Out:
# False

# %%
not 1 == 1 #direkt olumsuza cevirir.
# Out:
# False

# %%
24 in [45,67,24] #listenin icinde var mı yok mu
# Out:
# True

# %%
12 not in [45,67,90] # listenin icinde var mmı yok mu nun tersini alir.
# Out:
# True

# %%
8 in [9,3,2]
# Out:
# False

# %%
my_dictionary = {"k":2,"l":7,"m":1}

# %%
10 in my_dictionary.values() # sozcugun icindeki deger
# Out:
# False

# %%
"m" in my_dictionary.keys() # anahtar
# Out:
# True

# %%
3 in (3,4,5,6)
# Out:
# True

# %%
my_superhero = "Batman"

# %%
my_superhero == "Batman"
# Out:
# True

# %%
my_superhero == "Superman"
# Out:
# False

# %%
if my_superhero == "Batman":
    print("batman")
    print("duygu")
########--------########
print("hello world")
# Out:
# batman
# duygu
# hello world

# %%
if 6 > 9:
    print("hello python")
    print("duygu") # ifade yanlis aldugu icin cıktı olmaz

# %%
my_superhero = input("enter superhero: ")
# Out:
# enter superhero:  Superman

# %%
if my_superhero == "Superman":
    print("superman")
elif my_superhero == "Batman": #elif ( else if )
    print("batman")
elif my_superhero == "Aquaman" :
    print("aquaman")
elif my_superhero == "Ironman":
    print("ironman")
else:
    print(":(")
# Out:
# superman

# %%
my_age = 100

# %%
if my_age <= 18:
    print("age <= 18")
elif my_age > 18 and my_age <= 30:
    print("18 - age - 30")
elif my_age > 30 and my_age <= 40:
    print("30 - age - 40")
else:
    print("age > 40")
# Out:
# age > 40

# %%
my_superhero = input("enter superhero: ")
# Out:
# enter superhero:  Batman

# %%
my_superhero_list = ["Superman","Ironman","Thor","Blackwindow"]

# %%
if my_superhero in my_superhero_list:
    print(":)")
else:
    print(":(")
# Out:
# :(

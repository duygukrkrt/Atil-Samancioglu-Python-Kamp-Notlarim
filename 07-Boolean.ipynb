# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBoolean = True

# %%
type(myBoolean)
# Out:
# bool

# %%
myBoolean = False

# %%
5 > 3
# Out:
# True

# %%
5 < 3
# Out:
# False

# %%
age = input ("enter age: ")
# Out:
# enter age:  21

# %%
age
# Out:
# '21'

# %%
int(age) > 18
# Out:
# True

# %%
13+6
# Out:
# 19

# %%
19*7
# Out:
# 133

# %% [markdown]
# # variables

# %%
350/23
# Out:
# 15.217391304347826

# %%
900/5
# Out:
# 180.0

# %%
20-50
# Out:
# -30

# %%
3 * 3 * 3 * 3 * 3
# Out:
# 243

# %%
3*3*3*3*3
# Out:
# 243

# %%
5+6
# Out:
# 11

# %%
30/3
# Out:
# 10.0

# %%
40*4
# Out:
# 160

# %%
age = 21

# %%
age*4
# Out:
# 84

# %%
age/3
# Out:
# 7.0

# %%
age*21
# Out:
# 441

# %%
#data type

# %%
type(25)
# Out:
# int

# %%
type(43*5)
# Out:
# int

# %%
type(age*2)
# Out:
# int

# %%
# int -> integer

# %%
# int eksi değerler de tam sayı olduğu sürece int tipindendir.

# %%
type(-23)
# Out:
# int

# %%
x = -34

# %%
type(x)
# Out:
# int

# %%
type(3.14)
# Out:
# float

# %%
# float -> floating point

# %%
pi = 3.14

# %%
pi*3
# Out:
# 9.42

# %%
x + pi
# Out:
# -30.86

# %%
x
# Out:
# -34

# %%
x / pi
# Out:
# -10.828025477707007

# %%
x = 30

# %%
x = 25

# %%
x + 45
# Out:
# 70

# %%
myFloat=2.645245273

# %%
type(myFloat)
# Out:
# float

# %%
# camelCase İlk kelimenin ilk harfi küçük, sonraki kelimelerin baş harfi büyük yazılır.

# %%
# snake_case: Kelimelerin arasına alt çizgi (_) konur.

# %%
45/2
# Out:
# 22.5

# %%
type (45 / 2 )
# Out:
# float

# %%
50 / 8
# Out:
# 6.25

# %%
50 / 11
# Out:
# 4.545454545454546

# %%
6 / 3
# Out:
# 2.0

# %%
8.0 / 3.0
# Out:
# 2.6666666666666665

# %%
type ( 5 )
# Out:
# int

# %%
type ( 5.0 )
# Out:
# float

# %%
3 * 7
# Out:
# 21

# %%
3 + 7
# Out:
# 10

# %%
3 - 7
# Out:
# -4

# %%
3.0 - 7
# Out:
# -4.0

# %%
3.67 - 7
# Out:
# -3.33

# %%
type ( 3.58 - 7)
# Out:
# float

# %%
3.56 * 7.53
# Out:
# 26.806800000000003

# %%
3.45 - 10*4.78
# Out:
# -44.35

# %%
6.567 - 19*8958
# Out:
# -170195.433

# %%
9.09-44.6*5.0
# Out:
# -213.91

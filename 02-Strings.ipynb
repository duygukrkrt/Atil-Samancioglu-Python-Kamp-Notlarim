# %%
"hello python"
# Out:
# 'hello python'

# %%
print( "hello python " )
# Out:
# hello python

# %%
name = "duygu"

# %%
type (name)
# Out:
# str

# %%
'cyber security specialist duygu'
# Out:
# 'cyber security specialist duygu'

# %%
"cyber security specialist duygu"
# Out:
# 'cyber security specialist duygu'

# %%
"duygu's photography studio"
# Out:
# "duygu's photography studio"

# %%
name = "duygu"

# %%
type(name)
# Out:
# str

# %%
name = "duygu karakurt"

# %%
name.capitalize()
# Out:
# 'Duygu karakurt'

# %%
# String'in ilk harfini büyük yapar ve kalan bütün harflerini küçük bırakır.

# %%
name.capitalize
# Out:
# <function str.capitalize()>

# %%
#Eğer foksiyonun sonuna parantez açıp kapatmazsan, python o fonksiyonu çalıştıramaz.Yani bir fonksiyonu çalıştırmak istiyorsan mutlaka parantez koymalısın.

# %%
name
# Out:
# 'duygu karakurt'

# %%
x = 10

# %%
x = 50

# %%
help(name.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
#help() fonksiyonu herhangi bir fonksiyonun, metodun veya veri tipinin ne işe yaradığını ve nasıl kullanıldığını anlatır.

# %%
help(name.capitalize)
# Out:
# Help on built-in function capitalize:
#
# capitalize() method of builtins.str instance
#     Return a capitalized version of the string.
#
#     More specifically, make the first character have upper case and the rest lower
#     case.

# %%
name
# Out:
# 'duygu karakurt'

# %%
#count() karakter sayar.

# %%
name.count("u")
# Out:
# 3

# %%
name.count("k")
# Out:
# 2

# %%
name.count("m")
# Out:
# 0

# %%
#upper harfleri büyük harf yapar, kalıcı olarak bir değişim yoktur.

# %%
name.upper()
# Out:
# 'DUYGU KARAKURT'

# %%
name
# Out:
# 'duygu karakurt'

# %%
x = 45
y=9

# %%
x + y
# Out:
# 54

# %%
z = x + y

# %%
z
# Out:
# 54

# %%
#değişikliği kalıcı hale getirme yani yeniden atama yapma

# %%
nameUpper = name.upper()

# %%
nameUpper
# Out:
# 'DUYGU KARAKURT'

# %%
name
# Out:
# 'duygu karakurt'

# %%
print(name.upper())
# Out:
# DUYGU KARAKURT

# %%
help(name.upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %%
#length-len() metnin uzunluğunu bulma

# %%
len(name)
# Out:
# 14

# %%
print("duygu karakurt")
# Out:
# duygu karakurt

# %%
# \n alt satıra geçme karakteri

# %%
print("duygu \nkarakurt")
# Out:
# duygu
# karakurt

# %%
# \t bir tab tuşu kadar boşluk bırakır.

# %%
print("duygu \tkarakurt")
# Out:
# duygu 	karakurt

# %% [markdown]
# # index

# %%
myString = "hello world"

# %%
myString[4]
# Out:
# 'o'

# %%
myString[8]
# Out:
# 'r'

# %%
myString
# Out:
# 'hello world'

# %%
len(myString)
# Out:
# 11

# %%
myString = "duygu karakurt"

# %%
myString[7]
# Out:
# 'a'

# %%
len(myString)
# Out:
# 14

# %%
# len() - 1 metnin son harfinin indeks numarasını verir.

# %%
len(myString) - 1
# Out:
# 13

# %%
myString[len(myString)-1] # metnin son karakterini bulma
# Out:
# 't'

# %%
myString[-1]
# Out:
# 't'

# %%
myString[-2]
# Out:
# 'r'

# %%
barcode = "KLMNFSH7361264326482"

# %%
barcode[9]
# Out:
# '6'

# %%
barcode[0]
# Out:
# 'K'

# %%
36 + 78
# Out:
# 114

# %%
"K" + "L"
# Out:
# 'KL'

# %%
name = "duygu"

# %%
surname= "karakurt"

# %%
fullname = name + " " + surname

# %%
fullname
# Out:
# 'duygu karakurt'

# %%
fullname * 4
# Out:
# 'duygu karakurtduygu karakurtduygu karakurtduygu karakurt'

# %%
23 * "k"
# Out:
# 'kkkkkkkkkkkkkkkkkkkkkkk'

# %%
#slicing, starting index, stopping index, stepping size

# %%
# metin[başlangıç: bitiş: atlama miktarı]

# %%
barcode
# Out:
# 'KLMNFSH7361264326482'

# %%
barcode[::]
# Out:
# 'KLMNFSH7361264326482'

# %%
barcode[2::]
# Out:
# 'MNFSH7361264326482'

# %%
barcode[:7:]
# Out:
# 'KLMNFSH'

# %%
barcode[::7]
# Out:
# 'K73'

# %%
barcode[3:7:1]
# Out:
# 'NFSH'

# %%
name = "duygu karakurt"

# %%
name.index("u") #metnin içinde aranılan bir harfi veya kelimenin ilk karşılaştığı numarasını verir.
# Out:
# 1

# %%
name.split() # bir metni belirttiğin bir karaklere göre parçalara böler
# Out:
# ['duygu', 'karakurt']

# %%
type(name.split())
# Out:
# list

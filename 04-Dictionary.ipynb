# %%
#key - value pairing

# %%
fruit_list = ["orange","cherry"]

# %%
calorie_list = [125,104]

# %%
fruit_list[0]
# Out:
# 'orange'

# %%
calorie_list[0]
# Out:
# 125

# %%
fitness_dictionary = {"orange" :125, "cherry" :104}

# %%
type(fitness_dictionary)
# Out:
# dict

# %%
fitness_dictionary["cherry"]
# Out:
# 104

# %%
fitness_dictionary.keys() #anahtar kelimeler
# Out:
# dict_keys(['orange', 'cherry'])

# %%
fitness_dictionary.values() #atanan değerler
# Out:
# dict_values([125, 104])

# %%
type(fitness_dictionary.values())
# Out:
# dict_values

# %%
list(fitness_dictionary.values())
# Out:
# [125, 104]

# %%
fitness_dictionary
# Out:
# {'orange': 125, 'cherry': 104}

# %%
fitness_dictionary["cherry"] = 180

# %%
fitness_dictionary
# Out:
# {'orange': 125, 'cherry': 180}

# %%
fitness_dictionary["grape"] = 200

# %%
fitness_dictionary
# Out:
# {'orange': 125, 'cherry': 180, 'grape': 200}

# %%
fitness_dictionary.get("chery",0)
# Out:
# 0

# %%
fitness_dictionary
# Out:
# {'orange': 125, 'cherry': 180, 'grape': 200}

# %%
my_dictionary = {50 :"k",100 :"l",150 :"m"}

# %%
my_dictionary [100]
# Out:
# 'l'

# %%
my_dictionary[50]
# Out:
# 'k'

# %%
my_dictionary = {"key1":"value1","key2":"value2","key3":"value3"}

# %%
my_dictionary["key1"]
# Out:
# 'value1'

# %%
my_mixed_dictionary = {"key4":1,"key5":8.56,"key6":[94,34,26]}

# %%
my_mixed_dictionary["key6"][1]
# Out:
# 34

# %%
last_dictionary = {"k1" : 23,"k2" :[12,56,28,78,34,82,67,90],"k3" :"string","k4" :{"m":2,"n":3}}

# %%
last_dictionary["k2"][4]
# Out:
# 34

# %%
last_dictionary["k4"]["n"]
# Out:
# 3

# %%
myList = [15,"k","l",0.2]

# %%
myList[1] #1.indeksteki eleman çağırılır.
# Out:
# 'k'

# %%
myList[1] = 12 #1.indeksteki eleman değişir.

# %%
myList
# Out:
# [15, 12, 'l', 0.2]

# %%
#tuple

# %%
myTuple = (23,"m","n",2.6) # tuple tanımlanırken köşeli parantaz yerine normal parantez kullanılır.

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple[0]
# Out:
# 23

# %%
# my Tuple[09 = 100 -tuple tanımlandıktan sonra elemanları değiştirilemez.

# %%
#immutability(değiştirilemezlik) Bir kere tanımlandıktan sonra eleman ekleyemez, silemez veya değiştirilemez.

# %%
myTuple
# Out:
# (23, 'm', 'n', 2.6)

# %%
myTuple.index("n")
# Out:
# 2

# %%
myTuple.count("n") #kaç kez tekrar ettiğini sayar
# Out:
# 1

# %%
resultTuple = (12,53,78)

# %%
resultTuple
# Out:
# (12, 53, 78)

# %%
resultList = list(resultTuple)

# %%
resultList
# Out:
# [12, 53, 78]
